# %% [markdown]
# $$
# \text{非线性回归模型 (Non-Linear Regression Model)} \\ \quad \\
# \text{首先先确定模型, 观察散点图}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

np.set_printoptions(suppress=True)

times = np.arange(1, 17)
volumes = np.array([
    np.nan, 6.42, 8.20, 9.58, 9.50, 9.70, 10.00, 9.93, 
    9.99, 10.49, 10.59, 10.60, 10.80, 10.60, 10.90, 10.76
])

# %%
plt.figure(figsize=(4, 3))
plt.scatter(times, volumes)

# %% [markdown]
# $$
# \text{根据散点图, 可以确定模型为} \\ \quad \\
# y = ae^{\frac{b}{x}} \\ \quad \\
# \text{取对数} \\ \quad \\
# \ln (y) = \ln (a) + \frac{b}{x} \ln (e) = \ln (a) + \frac{b}{x} \\ \quad \\
# \text{令 } \hat{y} = \ln(y),  x' = \frac{1}{x}, \hat{b} = \ln(a), \hat{A} = b \\ \quad \\
# \text{则模型为} \\ \quad \\
# \hat{y} = \hat{b} + \hat{A} x' \\ \quad \\
# \text{接着求线性回归模型}
# $$

# %%
hat_y = np.log(volumes[1:])
prime_x = 1 / times[1:]
n = volumes.size - 1
sum_xy = (hat_y * prime_x).sum()
sum_x = prime_x.sum()
sum_y = hat_y.sum()
sum_x2 = (prime_x ** 2).sum()
x_bar = sum_x / n
y_bar = sum_y / n

hat_A = (n * sum_xy - sum_y * sum_x) / (n * sum_x2 - sum_x ** 2)
hat_b = y_bar - hat_A * x_bar
a = np.exp(hat_b)
print(f'hat_A = {hat_A}')
print(f'hat_b = {hat_b}')
print(f'a = {a}')
# Out:
# hat_A = -1.1106713597786577
# hat_b = 2.457784685487524
# a = 11.678910401287496

# %% [markdown]
# $$
# \text{所以回归模型为} \\ \quad \\
# \textbf{y = } 11.67891 e^{\frac{-1.11067}{x}} \\ \quad \\
# $$

# %%
plt.figure(figsize=(4, 3))
plt.scatter(times, volumes)
plt.plot(times, a * np.exp(hat_A / times), color='red', marker='o')

# %% [markdown]
# $$
# \text{常见的六类曲线} \\ \quad \\
# \text{双曲线 (Hyperbola)} \\ \quad \\
# \left\{
# \begin{array}{l}
# \hat{y} = \frac{x}{a + bx} \\
# \hat{y} = \frac{a + bx}{x} \\
# \hat{y} = \frac{1}{a + bx} \\
# \end{array}
# \right\}
# $$

# %% [markdown]
# $$
# \hat{y} = \frac{x}{a + bx} \\
# \text{两边去倒数} \implies \frac{1}{\hat{y}} = \frac{a + bx}{x} \\
# \text{两边同时乘以 x} \implies \frac{x}{\hat{y}} = a + bx \\
# \text{令 } y' = \frac{x}{\hat{y}}, A = a, B = b \\
# y' = A + Bx
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

def get_y(a, b, x):
    # 使用 np.where 避免除零警告
    denom = a + b * x
    return np.divide(x, denom, out=np.zeros_like(x), where=denom!=0)

a_list, b_list = [1, -1, 1, -1], [1, 1, -1, -1]
x = np.linspace(-10, 10, 400) # 减小范围并增加采样点以获得更平滑的曲线

fig, axs = plt.subplots(2, 2, figsize=(8, 6))
for i in range(4):
    a, b = a_list[i], b_list[i]
    y = get_y(a, b, x)
    ax = axs[i // 2, i % 2]
    
    # 绘制主曲线（处理断点避免连线）
    y[np.abs(y) > 20] = np.nan 
    ax.plot(x, y, label=f'y = x / ({a} + {b}x)', color='blue')
    
    # 水平渐近线: y = 1/b
    ax.axhline(y=1/b, color='r', linestyle='--', label=f'y = 1/{b}')
    
    # 垂直渐近线: x = -a/b
    ax.axvline(x=-a/b, color='g', linestyle='--', label=f'x = -{a}/{b}')
    
    ax.plot(x, x / y, color='orange', linestyle='--', label=f'y\' = x / y')
    
    ax.set_ylim(-10, 10)
    ax.legend(fontsize='small')
    ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# $$
# \hat{y} = \frac{a + bx}{x} \\
# \text{两边同时乘以 x} \implies \hat{y}x = a + bx \\
# \text{令 } y' = \hat{y}x, A = a, B = b \\
# y' = A + Bx
# $$

# %%
a, b = 2, 1
x = np.linspace(-10, 10, 400)
y = (a + b * x) / x

plt.figure(figsize=(4, 3))
plt.plot(x, y, label=f'y = ({a} + {b}x) / x', color='blue')
plt.axhline(y=1/b, color='r', linestyle='--', label=f'y = 1/{b}')    
plt.axvline(x=0, color='g', linestyle='--', label=f'x = 0')

plt.plot(x, x * y, color='orange', linestyle='--', label=f'y = x * ({a} + {b}x)')

plt.legend(fontsize='small')
plt.grid(True, alpha=0.3)
plt.ylim(-10, 10)
plt.legend()
plt.show()

# %% [markdown]
# $$
# \text{双倒数变换 (林贝方程 Lineweaver-Burke plot)} \\
# \hat{y} = \frac{1}{a + bx} \\
# \text{两边去倒数 } \implies \frac{1}{\hat{y}} = a + bx \\
# \text{令 } y' = \frac{1}{\hat{y}}, A = a, B = b \\
# y' = A + Bx \\
# $$

# %%
a, b = 1, 1
x = np.linspace(-10, 10, 400)
y = 1 / (a + b * x)

plt.figure(figsize=(4, 3))
plt.plot(x, y, label=f'y = 1 / ({a} + {b}x)', color='blue')
plt.axhline(y=0, color='r', linestyle='--', label='y = 0')    
plt.axvline(x=-a/b, color='g', linestyle='--', label=f'x = -{a}/{b}')
plt.plot(x, 1 / y, color='orange', linestyle='--', label=f'y = 1 / ({a} + {b}x)')
plt.legend(fontsize='small')
plt.grid(True, alpha=0.3)
plt.ylim(-10, 10)
plt.legend()
plt.show()

# %% [markdown]
# $$
# \text{幂函数曲线 (Power Function)} \\
# \hat{y} = a x^b \\
# \text{两边取对数} \implies \ln(\hat{y}) = \ln(a + x^b) = \ln(a) + \ln(x^b) = \ln(a) + b \ln(x) \\
# \text{令 } y' = \ln(\hat{y}), A = \ln(a), B = b,  x' = \ln(x) \\
# y' = A + B x' \\
# $$

# %%
from matplotlib.pyplot import spy
def get_y(a, b, x):
    return a * x**b

a, b = [1, 1, 1], [2, 0.5, -1]
x = np.linspace(0.1, 10, 400)

fig, axs = plt.subplots(1, 3, figsize=(10, 3))
for i in range(len(a)):
    y = get_y(a[i], b[i], x)
    
    ax = axs[i]
    ax.plot(x, y, label=f'y = {a[i]} x^{b[i]}', color='b')
    ax.plot(np.log(x), np.log(y), label=f'ln(y) = ln({a[i]}) + {b[i]} ln(x)', color='r', linestyle='--', markersize=4)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.legend(fontsize='small')
    ax.grid(True, alpha=0.3)
    
plt.tight_layout()
plt.show()

# %%
x = np.linspace(0.1, 10, 100)
y = 2 * x**1.5  # 幂函数

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 3))

# 1. 原始空间：曲线
ax1.plot(x, y, 'b')
ax1.set_title("Original: y = 2 * x^1.5")
ax1.legend(fontsize='small')
ax1.grid(True, alpha=0.3)

# 2. 对数空间：直线 (Linearized)
# 注意：横纵坐标都取对数
ax2.plot(np.log(x), np.log(y), 'r')
ax2.set_title("Linearized: ln(y) = ln(2) + 1.5*ln(x)")
ax2.legend(fontsize='small')
ax2.grid(True, alpha=0.3)
# Out:
# /var/folders/df/djcgrds10x1f5xm4b11rcsp80000gn/T/ipykernel_88422/753497220.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend(fontsize='small')
# /var/folders/df/djcgrds10x1f5xm4b11rcsp80000gn/T/ipykernel_88422/753497220.py:16: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend(fontsize='small')

# %% [markdown]
# $$
# \text{指数函数曲线 (Exponential Function)} \\
# \left\{ \begin{array}{ll}
# \hat{y} = ae^{bx} \\
# \hat{y} = ab^x \\
# \end{array}
# \right\}
# $$

# %% [markdown]
# $$
# \hat{y} = ae^{bx} \\
# \text{两边取对数} \implies \ln(\hat{y}) = \ln(ae^{bx}) = \ln(a) + bx \\
# \text{令 } y' = \ln(\hat{y}), A = \ln(a) \\
# y' = A + Bx \\
# $$

# %%
def get_y(x, a, b):
    return a * np.exp(b * x)

fig, axs = plt.subplots(1, 2, figsize=(8, 3))
a, b = 1, 1
x = np.linspace(0, 2, 100)
y = get_y(x, a, b)
axs[0].set_title('y = a * exp(b * x)')
axs[0].plot(x, y, label=f'y = {a} * exp({b} * x)', color='b')
axs[0].plot(x, np.log(y), label='linearized', color='g')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y')
axs[0].legend(fontsize='small')
axs[0].grid(True, alpha=0.3)

a, b = 6, -2
y = get_y(x, a, b)
axs[1].plot(x, y, label=f'y = {a} * exp({b} * x)', color='b')
axs[1].plot(x, np.log(y), label='linearized', color='g')
axs[1].set_xlabel('x')
axs[1].set_ylabel('y\'')
axs[1].legend(fontsize='small')
axs[1].grid(True, alpha=0.3)

# %% [markdown]
# $$
# \hat{y} = ab^x \\
# \text{两边取对数} \implies \ln (\hat{y}) = \ln (ab^x) = \ln (a) + \ln (b^x) = \ln (a) + x\ln (b) \\
# \text{令 } y' = \ln (\hat{y}), A = \ln (a), B = \ln (b) \\
# y' = A + Bx \\
# $$

# %%
def get_y(x, a, b):
    return a * (b ** x)

a, b = 2, 2
x = np.linspace(0, 2, 100)
y = get_y(x, a, b)
plt.figure(figsize=(4, 3))
plt.plot(x, y, label=f'y = {a} * b^x', color='b')
plt.plot(x, np.log(y), label='linearized', color='g')
plt.legend(fontsize='small')
plt.grid(True, alpha=0.3)

# %% [markdown]
# $$
# \text{倒指数函数曲线 (Inverted Exponential Function) (used in Arrhenius equation)} \\
# \hat{y} = ae^{\frac{b}{x}} \\
# \text{两边取对数 } \ln(\hat{y}) = \ln(ae^{\frac{b}{x}}) = \ln(a) + \ln(e^{\frac{b}{x}}) = \ln(a) + \frac{b}{x} \\
# \text{令 } y' = \ln(\hat{y}), x' = \frac{1}{x}, A = \ln(a) \\
# y' = A + Bx'
# $$

# %%
def get_y(x, a, b):
    return a * np.exp(b / x)

fig, axs = plt.subplots(1, 2, figsize=(8, 3)) # 稍微加宽一点

a, b1, b2 = 1, 1, -5
x = np.linspace(0.1, 0.2, 100)

# --- 左图：原始函数 (使用对数 Y 轴) ---
y1 = get_y(x, a, b1)
y2 = get_y(x, a, b2)

axs[0].plot(x, y1, label=f'a={a}, b={b1}', color='b')
axs[0].plot(x, y2, label=f'a={a}, b={b2}', color='g')
axs[0].set_yscale('log')  # <--- 关键修改：让极小值也能显现
axs[0].set_title('Original Space (Log Y-axis)')
axs[0].set_xlabel('x')
axs[0].set_ylabel('y (log scale)')
axs[0].legend()
axs[0].grid(True, which="both", alpha=0.3)

# --- 右图：线性化空间 ---
axs[1].plot(1/x, np.log(y1), color='b', label=f'ln(y) a={a}, b={b1}')
axs[1].plot(1/x, np.log(y2), color='g', label=f'ln(y) a={a}, b={b2}')
axs[1].set_title('Linearized Space')
axs[1].set_xlabel('1/x')
axs[1].set_ylabel('ln(y)')
axs[1].legend()
axs[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# $$
# \text{对数函数曲线} \\
# \hat{y} = a + b\ln(x) \text{, x > 0} \\
# \text{令 } y' = \hat{y}, x' = \ln(x) \\
# y' = A + Bx' \\
# $$

# %%
def get_y(a, b, x):
    return a + b * np.log(x)

x = np.linspace(0.1, 10, 100)
a, b = 1, 2
y = get_y(a, b, x)

plt.figure(figsize=(8, 3))
plt.subplot(1, 2, 1)
plt.title(f'y = {a} + {b} * ln(x)')
plt.plot(x, y, label=f'a={a}, b={b}', color='b')

a, b = 1, -2
y = get_y(a, b, x)
plt.plot(x, y, label=f'a={a}, b={b}', color='r')
plt.grid(True, which="both", alpha=0.3)
plt.legend(fontsize='small')
plt.xlabel('x')
plt.ylabel('y')

a, b = 1, 2
y = get_y(a, b, x)

plt.subplot(1, 2, 2)
plt.title('Linearized Regression')
plt.plot(np.log(x), y, label=f'a={a}, b={b}', color='b')

a, b = 1, -2
y = get_y(a, b, x)

plt.plot(np.log(x), get_y(a, b, x), label=f'a={a}, b={b}', color='r')
plt.grid(True, which="both", alpha=0.3)
plt.legend(fontsize='small')
plt.xlabel('ln(x)')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# $$
# \text{S型曲线 (Sigmoid Curve)} \\
# \hat{y} = \frac{k}{1 + ae^{-bx}}, \text{a, b, k > 0} \\
# \text{x = 0, } \hat{y} = \frac{k}{1 + a}; \quad x \rightarrow \infty \text{, } \hat{y} = k \\
# \text{两边取倒数 } \frac{1}{\hat{y}} = \frac{1 + ae^{-bx}}{k} \\
# \frac{k}{\hat{y}} - 1 = ae^{-bx} \implies \frac{k - \hat{y}}{\hat{y}} = ae^{-bx} \\
# \text{两边取对数 } \ln(\frac{k - \hat{y}}{\hat{y}}) = \ln(ae^{-bx}) = \ln(a) + \ln(e^{-bx}) = \ln{a} - bx \\
# \text{令 } y' = \ln(\frac{k - \hat{y}}{\hat{y}}), A = \ln(a) \\
# y' = A + Bx \\
# $$

# %%
def get_y(a, b, k, x):
    return k / (1 + a * np.exp(-b * x))

a, b, k = 100, 0.5, 5
x = np.linspace(0, 20, 50)
y = get_y(a, b, k, x)

plt.figure(figsize=(8, 3))
plt.subplot(1, 2, 1)
plt.title('y = k / (1 + a * exp(-b * x))')
plt.plot(x, y, label=f'a={a}, b={b}, k={k}', color='b')
plt.axvline(x=np.log(a) / b, color='r', linestyle='--', linewidth=1, label=f'x= np.log({a}) / {b}')
plt.axhline(y=k / 2, color='g', linestyle='--', linewidth=1, label=f'y= {k} / 2')
plt.grid(True, which="both", alpha=0.3)
plt.legend(fontsize='small')
plt.xlabel('x')
plt.ylabel('y')

plt.subplot(1, 2, 2)
plt.title('Linearized')
plt.plot(x, np.log((k - y) / y), label=f'y= np.log(({k} - y) / y)', linestyle='--', color='b')
plt.grid(True, which="both", alpha=0.3)
plt.legend(fontsize='small')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# $$
# \text{多项式回归模型 (Polynomial Regression)} \\
# Y = \beta_0 + \beta_1 x + \beta_2 x^2 + \cdots + \beta_p x^p + \epsilon \\
# \text{其中 p 是已知的, } \beta_i(i = 0, 1, 2, \cdots, p) \text{ 是未知参数, } \epsilon \text{ 是服从正态分布} N(0, \sigma) \\ \quad \\
# \text{回归多项式为} \\
# Y = \beta_0 + \beta_1 x + \beta_2 x^2 + \cdots + \beta_p x^p \\
# $$

# %% [markdown]
# $$
# \text{一元多项式回归模型 (Polynomial Regression)} \\
# \text{Y = } \beta_0 + \beta_1 x + \beta_2 x^2 + \epsilon \\ \quad \\
# $$

# %%
# 时间 t (s) - 修正了原图中的笔误 6/60 和 10/.30
t_values = np.array([
    1/30, 2/30, 3/30, 4/30, 5/30, 6/30, 7/30, 
    8/30, 9/30, 10/30, 11/30, 12/30, 13/30, 14/30
])

# 位移 s (cm)
s_values = np.array([
    11.86, 15.67, 20.60, 26.69, 33.71, 41.93, 51.13,
    61.49, 72.90, 85.44, 99.08, 113.77, 129.54, 146.48
])

# 如果需要将它们组合成一个 14x2 的矩阵
data = np.vstack((t_values, s_values)).T

# %%
X = np.ones((14, 3))
X[:, 1] = data[:, 0]
X[:, 2] = t_values ** 2
Y = data[:, 1]
beta_0, beta_1, beta_2 = np.linalg.inv(X.T @ X) @ X.T @ Y

# %%
x = X[:, 1]
y = Y
y_pred = beta_0 + beta_1 * x + beta_2 * x * x

plt.figure(figsize=(4, 3))
plt.scatter(x, y, color='red', label='Raw data')
plt.plot(x, y_pred, linestyle='--', color='blue', label='Predicted')
plt.grid(True, which="both", alpha=0.3)
plt.legend(fontsize='small')
plt.xlabel('time t')
plt.ylabel('distance s')
plt.tight_layout()

# %% [markdown]
# $$
# \text{多元二项式回归模型} \\
# \text{Y = } \beta_0 + \beta_1 x_1 + \beta_2 x_2 + \epsilon \\ \quad \\
# $$

# %%
# 需求量 (Demand)
demand = np.array([100, 75, 80, 70, 50, 65, 90, 100, 110, 60])

# 收入 (Income)
income = np.array([1000, 600, 1200, 500, 300, 400, 1300, 1100, 1300, 300])

# 价格 (Price)
price = np.array([5, 7, 6, 6, 8, 7, 5, 4, 3, 9])

# 如果需要整合到一个矩阵中 (3行10列)
data = np.vstack([demand, income, price]).T

# %%
Y = data[:, 0]
X = np.concatenate([np.ones((data.shape[0], 1)), data[:, 1:]], axis=1)
X = np.concatenate([X, data[:, 1:] ** 2], axis=1)
beta = np.linalg.inv(X.T @ X) @ X.T @ Y
beta
# Out:
# array([110.5312739 ,   0.14643066, -26.57093651,  -0.00007557,
#          1.84749312])

# %%
plt.figure(figsize=(8, 3))
plt.subplot(1, 2, 1)
plt.scatter(X[:, 1], Y, marker='o', color='blue', label='Raw data')
plt.scatter(X[:, 1], X @ beta, marker='x', color = 'red', label='Predicted')
plt.xlabel('x1 (income)')
plt.ylabel('y (demand)')
plt.grid(True, which="both", alpha=0.3)
plt.legend(fontsize='small')
plt.tight_layout()

plt.subplot(1, 2, 2)
plt.scatter(X[:, 2], Y, marker='o', color='blue', label='Raw data')
plt.scatter(X[:, 2], X @ beta, marker='x', color = 'red', label='Predicted')
plt.xlabel('x2 (prices)')
plt.ylabel('y (demand)')
plt.grid(True, which="both", alpha=0.3)
plt.legend(fontsize='small')
plt.tight_layout()
plt.show()

# %%
MSE = np.sum((Y - X @ beta) ** 2) / (X.shape[0] - X.shape[1])
RMSE = np.sqrt(MSE)
RMSE
# Out:
# 4.536196580798924

# %%
x_1, x_2 = 1000, 6
y = beta[0] + beta[1] * x_1 + beta[2] * x_2 + beta[3] * x_1 ** 2 + beta[4] * x_2 ** 2
y
# Out:
# 88.47913168104859
